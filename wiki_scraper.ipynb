# %%
from requests import get
from bs4 import BeautifulSoup
from re import compile
from pandas import DataFrame
from gensim.utils import simple_preprocess
import wikipedia

# %%
# Set the base URL for the Wikipedia pages
base_url = 'https://en.wikipedia.org'
links_url = 'https://en.wikipedia.org/wiki/List_of_computer_scientists'

# %%
# make the request to the server
request = get(links_url)

# get the html content
response = BeautifulSoup(request.content, 'html')

# %%
content = response.find("div", {"class": "mw-parser-output"}).find_all("ul")

# %%
scientists = {}
for header in content:
    for scientist in header.find_all("li"):
        link = scientist.find("a", attrs={'href': compile("^/wiki/")})
        if link: scientists[link.text] = link.get("href")

# %%
# scientist_wiki_links = {}
# for s, l in zip(scientists[:-11], links[:-11]):
#     scientist_wiki_links[s] = base_url + l

# %%
scientists
# Out:
# {'Atta ur Rehman Khan': '/wiki/Atta_ur_Rehman_Khan',
#  'Wil van der Aalst': '/wiki/Wil_van_der_Aalst',
#  'Scott Aaronson': '/wiki/Scott_Aaronson',
#  'Rediet Abebe': '/wiki/Rediet_Abebe',
#  'Hal Abelson': '/wiki/Hal_Abelson',
#  'Serge Abiteboul': '/wiki/Serge_Abiteboul',
#  'Samson Abramsky': '/wiki/Samson_Abramsky',
#  'Leonard Adleman': '/wiki/Leonard_Adleman',
#  'Manindra Agrawal': '/wiki/Manindra_Agrawal',
#  'Luis von Ahn': '/wiki/Luis_von_Ahn',
#  'Alfred Aho': '/wiki/Alfred_Aho',
#  'Frances E. Allen': '/wiki/Frances_E._Allen',
#  'Gene Amdahl': '/wiki/Gene_Amdahl',
#  'David P. Anderson': '/wiki/David_P._Anderson',
#  'Lisa Anthony': '/wiki/Lisa_Anthony',
#  'Andrew Appel': '/wiki/Andrew_Appel',
#  'Cecilia R. Aragon': '/wiki/Cecilia_R._Aragon',
#  'Bruce Arden': '/wiki/Bruce_Arden',
#  'Sanjeev Arora': '/wiki/Sanjeev_Arora',
#  'Winifred "Tim" Alice Asprey': '/wiki/Winifred_Asprey',
#  'John Vincent Atanasoff': '/wiki/John_Vincent_Atanasoff',
#  'Shakuntala Atre': '/wiki/Shakuntala_Atre',
#  'Charles Babbage': '/wiki/Charles_Babbage',
#  'Charles Bachman': '/wiki/Charles_Bachman',
#  'Roland Carl Backhouse': '/wiki/Roland_Carl_Backhouse',
#  'John Backus': '/wiki/John_Backus',
#  'David F. Bacon': '/wiki/David_F._Bacon',
#  'David A. Bader': '/wiki/David_A._Bader',
#  'Victor Bahl': '/wiki/Victor_Bahl',
#  'Anthony James Barr': '/wiki/Anthony_James_Barr',
#  'Jean Bartik': '/wiki/Jean_Bartik',
#  'Andrew Barto': '/wiki/Andrew_Barto',
#  'Friedrich L. Bauer': '/wiki/Friedrich_L._Bauer',
#  'Rudolf Bayer': '/wiki/Rudolf_Bayer',
#  'Gordon Bell': '/wiki/Gordon_Bell',
#  'Steven M. Bellovin': '/wiki/Steven_M._Bellovin',
#  'Cecilia Berdichevsky': '/wiki/Cecilia_Berdichevsky',
#  'Tim Berners-Lee': '/wiki/Tim_Berners-Lee',
#  'Daniel J. Bernstein': '/wiki/Daniel_J._Bernstein',
#  'Peter Bernus': '/wiki/Peter_Bernus',
#  'Abhay Bhushan': '/wiki/Abhay_Bhushan',
#  'Dines Bjørner': '/wiki/Dines_Bj%C3%B8rner',
#  'Gerrit Blaauw': '/wiki/Gerrit_Blaauw',
#  'Sue Black': '/wiki/Sue_Black_(computer_scientist)',
#  'David Blei': '/wiki/David_Blei',
#  'Dorothy Blum': '/wiki/Dorothy_Blum',
#  'Lenore Blum': '/wiki/Lenore_Blum',
#  'Manuel Blum': '/wiki/Manuel_Blum',
#  'Barry Boehm': '/wiki/Barry_Boehm',
#  'Corrado Böhm': '/wiki/Corrado_B%C3%B6hm',
#  'Kurt Bollacker': '/wiki/Kurt_Bollacker',
#  'Jeff Bonwick': '/wiki/Jeff_Bonwick',
#  'Grady Booch': '/wiki/Grady_Booch',
#  'George Boole': '/wiki/George_Boole',
#  'Andrew Booth': '/wiki/Andrew_Donald_Booth',
#  'Kathleen Booth': '/wiki/Kathleen_Booth',
#  'Anita Borg': '/wiki/Anita_Borg',
#  'Bert Bos': '/wiki/Bert_Bos',
#  'Mikhail Botvinnik': '/wiki/Mikhail_Botvinnik',
#  'Jonathan Bowen': '/wiki/Jonathan_Bowen',
#  'Stephen R. Bourne': '/wiki/Stephen_R._Bourne',
#  'Harry Bouwman': '/wiki/Harry_Bouwman',
#  'Robert S. Boyer': '/wiki/Robert_S._Boyer',
#  'Karlheinz Brandenburg': '/wiki/Karlheinz_Brandenburg',
#  'Lawrence M. Breed': '/wiki/Lawrence_M._Breed',
#  'Jack E. Bresenham': '/wiki/Jack_E._Bresenham',
#  'Sergey Brin': '/wiki/Sergey_Brin',
#  'David J. Brown': '/wiki/David_J._Brown_(computer_scientist)',
#  'Per Brinch Hansen': '/wiki/Per_Brinch_Hansen',
#  'Sjaak Brinkkemper': '/wiki/Sjaak_Brinkkemper',
#  'Fred Brooks': '/wiki/Fred_Brooks',
#  'Rod Brooks': '/wiki/Rod_Brooks',
#  'Margaret Burnett': '/wiki/Margaret_Burnett',
#  'Michael Butler': '/wiki/Michael_Butler_(computer_scientist)',
#  'Tracy Camp': '/wiki/Tracy_Camp',
#  'Martin Campbell-Kelly': '/wiki/Martin_Campbell-Kelly',
#  'Rosemary Candlin': '/wiki/Rosemary_Candlin',
#  'Rod Canion': '/wiki/Rod_Canion',
#  'Bryan Cantrill': '/wiki/Bryan_Cantrill',
#  'Luca Cardelli': '/wiki/Luca_Cardelli',
#  'John Carmack': '/wiki/John_Carmack',
#  'Edwin Catmull': '/wiki/Edwin_Catmull',
#  'Vint Cerf': '/wiki/Vint_Cerf',
#  'Gregory Chaitin': '/wiki/Gregory_Chaitin',
#  'Robert Cailliau': '/wiki/Robert_Cailliau',
#  'Zhou Chaochen': '/wiki/Zhou_Chaochen',
#  'Peter Chen': '/wiki/Peter_Chen',
#  'Leonardo Chiariglione': '/wiki/Leonardo_Chiariglione',
#  'Tracy Chou': '/wiki/Tracy_Chou',
#  'Alonzo Church': '/wiki/Alonzo_Church',
#  'Alberto Ciaramella': '/wiki/Alberto_Ciaramella',
#  'Edmund M. Clarke': '/wiki/Edmund_M._Clarke',
#  'John Cocke': '/wiki/John_Cocke_(computer_scientist)',
#  'Edgar F. Codd': '/wiki/Edgar_F._Codd',
#  'Jacques Cohen': '/wiki/Jacques_Cohen_(computer_scientist)',
#  'Ian Coldwater': '/wiki/Ian_Coldwater',
#  'Simon Colton': '/wiki/Simon_Colton',
#  'Alain Colmerauer': '/wiki/Alain_Colmerauer',
#  'Douglas Comer': '/wiki/Douglas_Comer',
#  'Paul Justin Compton': '/wiki/Paul_Justin_Compton',
#  'Richard W. Conway': '/wiki/Richard_W._Conway',
#  'Gordon Cormack': '/wiki/Gordon_Cormack',
#  'Stephen Cook': '/wiki/Stephen_Cook',
#  'James Cooley': '/wiki/James_Cooley',
#  'Danese Cooper': '/wiki/Danese_Cooper',
#  'Fernando J. Corbató': '/wiki/Fernando_J._Corbat%C3%B3',
#  'Kit Cosper': '/wiki/Kit_Cosper',
#  'Patrick Cousot': '/wiki/Patrick_Cousot',
#  'Ingemar Cox': '/wiki/Ingemar_Cox',
#  'Seymour Cray': '/wiki/Seymour_Cray',
#  'Nello Cristianini': '/wiki/Nello_Cristianini',
#  'Jon Crowcroft': '/wiki/Jon_Crowcroft',
#  'W. Bruce Croft': '/wiki/W._Bruce_Croft',
#  'Glen Culler': '/wiki/Glen_Culler',
#  'Haskell Curry': '/wiki/Haskell_Curry',
#  'Luigi Dadda': '/wiki/Luigi_Dadda',
#  'Ole-Johan Dahl': '/wiki/Ole-Johan_Dahl',
#  'Ryan Dahl': '/wiki/Ryan_Dahl',
#  'Andries van Dam': '/wiki/Andries_van_Dam',
#  'Samir Das': '/wiki/Samir_Das',
#  'Neil Daswani': '/wiki/Neil_Daswani',
#  'Christopher J. Date': '/wiki/Christopher_J._Date',
#  'Jeff Dean': '/wiki/Jeff_Dean_(computer_scientist)',
#  'Erik Demaine': '/wiki/Erik_Demaine',
#  'Tom DeMarco': '/wiki/Tom_DeMarco',
#  'Richard DeMillo': '/wiki/Richard_DeMillo',
#  'Dorothy E. Denning': '/wiki/Dorothy_E._Denning',
#  'Peter J. Denning': '/wiki/Peter_J._Denning',
#  'Michael Dertouzos': '/wiki/Michael_Dertouzos',
#  'Alexander Dewdney': '/wiki/Alexander_Dewdney',
#  'Robert Dewar': '/wiki/Robert_Dewar',
#  'Vinod Dham': '/wiki/Vinod_Dham',
#  'Jan Dietz': '/wiki/Jan_Dietz',
#  'Whitfield Diffie': '/wiki/Whitfield_Diffie',
#  'Edsger Dijkstra': '/wiki/Edsger_Dijkstra',
#  'Matthew Dillon': '/wiki/Matthew_Dillon_(computer_scientist)',
#  'Alan Dix': '/wiki/Alan_Dix',
#  'Jack Dongarra': '/wiki/Jack_Dongarra',
#  'Marco Dorigo': '/wiki/Marco_Dorigo',
#  'Paul Dourish': '/wiki/Paul_Dourish',
#  'Charles Stark Draper': '/wiki/Charles_Stark_Draper',
#  'Susan Dumais': '/wiki/Susan_Dumais',
#  'Adam Dunkels': '/wiki/Adam_Dunkels',
#  'Jon Michael Dunn': '/wiki/Jon_Michael_Dunn',
#  'Schahram Dustdar': '/wiki/Schahram_Dustdar',
#  'Peter Eades': '/wiki/Peter_Eades',
#  'Annie Easley': '/wiki/Annie_Easley',
#  'Wim Ebbinkhuijsen': '/wiki/Wim_Ebbinkhuijsen',
#  'John Presper Eckert': '/wiki/John_Presper_Eckert',
#  'Alan Edelman': '/wiki/Alan_Edelman',
#  'Brendan Eich': '/wiki/Brendan_Eich',
#  'Philip Emeagwali': '/wiki/Philip_Emeagwali',
#  'E. Allen Emerson': '/wiki/E._Allen_Emerson',
#  'Douglas Engelbart': '/wiki/Douglas_Engelbart',
#  'Barbara Engelhardt': '/wiki/Barbara_Engelhardt',
#  'David Eppstein': '/wiki/David_Eppstein',
#  'Andrey Ershov': '/wiki/Andrey_Ershov',
#  'Don Estridge': '/wiki/Philip_Don_Estridge',
#  'Oren Etzioni': '/wiki/Oren_Etzioni',
#  'Christopher Riche Evans': '/wiki/Christopher_Riche_Evans',
#  'David C. Evans': '/wiki/David_C._Evans',
#  'Shimon Even': '/wiki/Shimon_Even',
#  'Scott Fahlman': '/wiki/Scott_Fahlman',
#  'Edward Feigenbaum': '/wiki/Edward_Feigenbaum',
#  'Edward Felten': '/wiki/Edward_Felten',
#  'Tim Finin': '/wiki/Tim_Finin',
#  'Raphael Finkel': '/wiki/Raphael_Finkel',
#  'Donald Firesmith': '/wiki/Donald_Firesmith',
#  'Gary William Flake': '/wiki/Gary_William_Flake',
#  'Tommy Flowers': '/wiki/Tommy_Flowers',
#  'Robert Floyd': '/wiki/Robert_W._Floyd',
#  'Sally Floyd': '/wiki/Sally_Floyd',
#  'Lawrence J. Fogel': '/wiki/Lawrence_J._Fogel',
#  'James D. Foley': '/wiki/James_D._Foley',
#  'Ken Forbus': '/wiki/Ken_Forbus',
#  'L. R. Ford, Jr.': '/wiki/L._R._Ford,_Jr.',
#  'Lance Fortnow': '/wiki/Lance_Fortnow',
#  'Mahmoud Samir Fayed': '/wiki/Mahmoud_Samir_Fayed',
#  'Martin Fowler': '/wiki/Martin_Fowler_(software_engineer)',
#  'Robert France': '/wiki/Robert_France',
#  'Herbert W. Franke': '/wiki/Herbert_W._Franke',
#  'Edward Fredkin': '/wiki/Edward_Fredkin',
#  'Yoav Freund': '/wiki/Yoav_Freund',
#  'Daniel P. Friedman': '/wiki/Daniel_P._Friedman',
#  'Charlotte Froese Fischer': '/wiki/Charlotte_Froese_Fischer',
#  'Ping Fu': '/wiki/Ping_Fu',
#  'Xiaoming Fu': '/wiki/Xiaoming_Fu',
#  'Kunihiko Fukushima': '/wiki/Kunihiko_Fukushima',
#  'D. R. Fulkerson': '/wiki/D._R._Fulkerson',
#  'Richard P. Gabriel': '/wiki/Richard_P._Gabriel',
#  'Zvi Galil': '/wiki/Zvi_Galil',
#  'Bernard Galler': '/wiki/Bernard_Galler',
#  'Hector Garcia-Molina': '/wiki/Hector_Garcia-Molina',
#  'Michael Garey': '/wiki/Michael_Garey',
#  'Hugo de Garis': '/wiki/Hugo_de_Garis',
#  'Bill Gates': '/wiki/Bill_Gates',
#  'David Gelernter': '/wiki/David_Gelernter',
#  'Lisa Gelobter': '/wiki/Lisa_Gelobter',
#  'Charles Geschke': '/wiki/Charles_Geschke',
#  'Zoubin Ghahramani': '/wiki/Zoubin_Ghahramani',
#  'Sanjay Ghemawat': '/wiki/Sanjay_Ghemawat',
#  'Jeremy Gibbons': '/wiki/Jeremy_Gibbons',
#  'Juan E. Gilbert': '/wiki/Juan_E._Gilbert',
#  'Lee Giles': '/wiki/Lee_Giles',
#  'Seymour Ginsburg': '/wiki/Seymour_Ginsburg',
#  'Robert L. Glass': '/wiki/Robert_L._Glass',
#  'Kurt Gödel': '/wiki/Kurt_G%C3%B6del',
#  'Ashok Goel': '/wiki/Ashok_Goel',
#  'Joseph Goguen': '/wiki/Joseph_Goguen',
#  'Hardik Gohel': '/wiki/Hardik_Gohel',
#  'E. Mark Gold': '/wiki/E._Mark_Gold',
#  'Adele Goldberg': '/wiki/Adele_Goldberg_(computer_scientist)',
#  'Andrew V. Goldberg': '/wiki/Andrew_V._Goldberg',
#  'Ian Goldberg': '/wiki/Ian_Goldberg',
#  'Judy Goldsmith': '/wiki/Judy_Goldsmith_(computer_scientist)',
#  'Oded Goldreich': '/wiki/Oded_Goldreich',
#  'Shafi Goldwasser': '/wiki/Shafi_Goldwasser',
#  'Gene Golub': '/wiki/Gene_Golub',
#  'Martin Charles Golumbic': '/wiki/Martin_Charles_Golumbic',
#  'Gastón Gonnet': '/wiki/Gast%C3%B3n_Gonnet',
#  'Ian Goodfellow': '/wiki/Ian_Goodfellow',
#  'James Gosling': '/wiki/James_Gosling',
#  'Paul Graham': '/wiki/Paul_Graham_(computer_programmer)',
#  'Robert M. Graham': '/wiki/Robert_M._Graham_(computer_scientist)',
#  'Susan L. Graham': '/wiki/Susan_L._Graham',
#  'Jim Gray': '/wiki/Jim_Gray_(computer_scientist)',
#  'Sheila Greibach': '/wiki/Sheila_Greibach',
#  'David Gries': '/wiki/David_Gries',
#  'Ralph Griswold': '/wiki/Ralph_Griswold',
#  'Bill Gropp': '/wiki/Bill_Gropp',
#  'Tom Gruber': '/wiki/Tom_Gruber',
#  'Shelia Guberman': '/wiki/Shelia_Guberman',
#  'Ramanathan V. Guha': '/wiki/Ramanathan_V._Guha',
#  'Neil J. Gunther': '/wiki/Neil_J._Gunther',
#  'Jürg Gutknecht': '/wiki/J%C3%BCrg_Gutknecht',
#  'Michael Guy': '/wiki/Michael_Guy',
#  'Robert Griesemer': '/wiki/Robert_Griesemer',
#  'Nico Habermann': '/wiki/Nico_Habermann',
#  'Philipp Matthäus Hahn': '/wiki/Philipp_Matth%C3%A4us_Hahn',
#  'Eldon C. Hall': '/wiki/Eldon_C._Hall',
#  'Wendy Hall': '/wiki/Wendy_Hall',
#  'Joseph Halpern': '/wiki/Joseph_Halpern',
#  'Margaret Hamilton': '/wiki/Margaret_Hamilton_(scientist)',
#  'Richard Hamming': '/wiki/Richard_Hamming',
#  'Jiawei Han': '/wiki/Jiawei_Han',
#  'Frank Harary': '/wiki/Frank_Harary',
#  'Juris Hartmanis': '/wiki/Juris_Hartmanis',
#  'Johan Håstad': '/wiki/Johan_H%C3%A5stad',
#  'Les Hatton': '/wiki/Les_Hatton',
#  'Igor Hawryszkiewycz': '/wiki/Igor_Hawryszkiewycz',
#  'He Jifeng': '/wiki/He_Jifeng',
#  'Eric Hehner': '/wiki/Eric_Hehner',
#  'Martin Hellman': '/wiki/Martin_Hellman',
#  'Gernot Heiser': '/wiki/Gernot_Heiser',
#  'James Hendler': '/wiki/James_Hendler',
#  'John L. Hennessy': '/wiki/John_L._Hennessy',
#  'Andrew Herbert': '/wiki/Andrew_Herbert',
#  'Carl Hewitt': '/wiki/Carl_Hewitt',
#  'Kelsey Hightower': '/wiki/Kelsey_Hightower',
#  'Danny Hillis': '/wiki/Danny_Hillis',
#  'Geoffrey Hinton': '/wiki/Geoffrey_Hinton',
#  'Julia Hirschberg': '/wiki/Julia_Hirschberg',
#  'Tin Kam Ho': '/wiki/Tin_Kam_Ho',
#  'C. A. R. Hoare': '/wiki/C._A._R._Hoare',
#  'Louis Hodes': '/wiki/Louis_Hodes',
#  'Betty Holberton': '/wiki/Betty_Holberton',
#  'John Henry Holland': '/wiki/John_Henry_Holland',
#  'Herman Hollerith': '/wiki/Herman_Hollerith',
#  'Gerard Holzmann': '/wiki/Gerard_Holzmann',
#  'John Hopcroft': '/wiki/John_Hopcroft',
#  'Grace Hopper': '/wiki/Grace_Hopper',
#  'Eric Horvitz': '/wiki/Eric_Horvitz',
#  'Alston Householder': '/wiki/Alston_Householder',
#  'Paul Hudak': '/wiki/Paul_Hudak',
#  'David A. Huffman': '/wiki/David_A._Huffman',
#  'John Hughes': '/wiki/John_Hughes_(computer_scientist)',
#  'Roger Hui': '/wiki/Roger_Hui',
#  'Watts Humphrey': '/wiki/Watts_Humphrey',
#  'Jean Ichbiah': '/wiki/Jean_Ichbiah',
#  'Roberto Ierusalimschy': '/wiki/Roberto_Ierusalimschy',
#  'Dan Ingalls': '/wiki/Dan_Ingalls',
#  'Mary Jane Irwin': '/wiki/Mary_Jane_Irwin',
#  'Kenneth E. Iverson': '/wiki/Kenneth_E._Iverson',
#  'Ivar Jacobson': '/wiki/Ivar_Jacobson',
#  'Anil K. Jain': '/wiki/Anil_K._Jain_(computer_scientist,_born_1948)',
#  'Ramesh Jain': '/wiki/Ramesh_Jain',
#  'Jonathan James': '/wiki/Jonathan_James',
#  'David S. Johnson': '/wiki/David_S._Johnson',
#  'Stephen C. Johnson': '/wiki/Stephen_C._Johnson',
#  'Cliff Jones': '/wiki/Cliff_Jones_(computer_scientist)',
#  'Michael I. Jordan': '/wiki/Michael_I._Jordan',
#  'Mathai Joseph': '/wiki/Mathai_Joseph',
#  'Aravind K. Joshi': '/wiki/Aravind_K._Joshi',
#  'Bill Joy': '/wiki/Bill_Joy',
#  'Dan Jurafsky': '/wiki/Dan_Jurafsky',
#  'William Kahan': '/wiki/William_Kahan',
#  'Robert E. Kahn': '/wiki/Robert_E._Kahn',
#  'Avinash Kak': '/wiki/Avinash_Kak',
#  'Poul-Henning Kamp': '/wiki/Poul-Henning_Kamp',
#  'David Karger': '/wiki/David_Karger',
#  'Richard Karp': '/wiki/Richard_Karp',
#  'Narendra Karmarkar': '/wiki/Narendra_Karmarkar',
#  'Marek Karpinski': '/wiki/Marek_Karpinski',
#  'Ted Kaehler': '/wiki/Ted_Kaehler',
#  'Alan Kay': '/wiki/Alan_Kay',
#  'Neeraj Kayal': '/wiki/Neeraj_Kayal',
#  'Manolis Kellis': '/wiki/Manolis_Kellis',
#  'John George Kemeny': '/wiki/John_George_Kemeny',
#  'Ken Kennedy': '/wiki/Ken_Kennedy_(computer_scientist)',
#  'Brian Kernighan': '/wiki/Brian_Kernighan',
#  'Carl Kesselman': '/wiki/Carl_Kesselman',
#  'Gregor Kiczales': '/wiki/Gregor_Kiczales',
#  'Peter T. Kirstein': '/wiki/Peter_T._Kirstein',
#  'Stephen Cole Kleene': '/wiki/Stephen_Cole_Kleene',
#  'Dan Klein': '/wiki/Dan_Klein',
#  'Leonard Kleinrock': '/wiki/Leonard_Kleinrock',
#  'Donald Knuth': '/wiki/Donald_Knuth',
#  'Andrew Koenig': '/wiki/Andrew_Koenig_(programmer)',
#  'Daphne Koller': '/wiki/Daphne_Koller',
#  'Michael Kölling': '/wiki/Michael_K%C3%B6lling',
#  'Andrey Nikolaevich Kolmogorov': '/wiki/Andrey_Nikolaevich_Kolmogorov',
#  'Janet L. Kolodner': '/wiki/Janet_L._Kolodner',
#  'David Korn': '/wiki/David_Korn_(computer_scientist)',
#  'Kees Koster': '/wiki/Cornelis_H._A._Koster',
#  'Robert Kowalski': '/wiki/Robert_Kowalski',
#  'John Koza': '/wiki/John_Koza',
#  'John Krogstie': '/wiki/John_Krogstie',
#  'Joseph Kruskal': '/wiki/Joseph_Kruskal',
#  'Maarja Kruusmaa': '/wiki/Maarja_Kruusmaa',
#  'Thomas E. Kurtz': '/wiki/Thomas_E._Kurtz',
#  'Richard E. Ladner': '/wiki/Richard_E._Ladner',
#  'Monica S. Lam': '/wiki/Monica_S._Lam',
#  'Leslie Lamport': '/wiki/Leslie_Lamport',
#  'Butler Lampson': '/wiki/Butler_Lampson',
#  'Peter Landin': '/wiki/Peter_Landin',
#  'Tom Lane': '/wiki/Tom_Lane_(computer_scientist)',
#  'Börje Langefors': '/wiki/B%C3%B6rje_Langefors',
#  'Chris Lattner': '/wiki/Chris_Lattner',
#  'Steve Lawrence': '/wiki/Steve_Lawrence_(computer_scientist)',
#  'Edward D. Lazowska': '/wiki/Edward_D._Lazowska',
#  'Joshua Lederberg': '/wiki/Joshua_Lederberg',
#  'Manny M Lehman': '/wiki/Manny_M_Lehman',
#  'Charles E. Leiserson': '/wiki/Charles_E._Leiserson',
#  'Douglas Lenat': '/wiki/Douglas_Lenat',
#  'Yann LeCun': '/wiki/Yann_LeCun',
#  'Rasmus Lerdorf': '/wiki/Rasmus_Lerdorf',
#  'Max Levchin': '/wiki/Max_Levchin',
#  'Leonid Levin': '/wiki/Leonid_Levin',
#  'Kevin Leyton-Brown': '/wiki/Kevin_Leyton-Brown',
#  'J.C.R. Licklider': '/wiki/J.C.R._Licklider',
#  'David Liddle': '/wiki/David_Liddle',
#  'Jochen Liedtke': '/wiki/Jochen_Liedtke',
#  'John Lions': '/wiki/John_Lions',
#  'Charles H. Lindsey': '/wiki/Charles_H._Lindsey',
#  'Richard J. Lipton': '/wiki/Richard_J._Lipton',
#  'Barbara Liskov': '/wiki/Barbara_Liskov',
#  'Yanhong Annie Liu': '/wiki/Yanhong_Annie_Liu',
#  'Darrell Long': '/wiki/Darrell_Long',
#  'Patricia D. Lopez': '/wiki/Patricia_D._Lopez',
#  'Gillian Lovegrove': '/wiki/Gillian_Lovegrove',
#  'Ada Lovelace': '/wiki/Ada_Lovelace',
#  'David Luckham': '/wiki/David_Luckham',
#  'Eugene Luks': '/wiki/Eugene_Luks',
#  'Nancy Lynch': '/wiki/Nancy_Lynch',
#  'Nadia Magnenat Thalmann': '/wiki/Nadia_Magnenat_Thalmann',
#  'Tom Maibaum': '/wiki/Tom_Maibaum',
#  'Zohar Manna': '/wiki/Zohar_Manna',
#  'James Martin': '/wiki/James_Martin_(author)',
#  'Robert C. Martin': '/wiki/Robert_C._Martin',
#  'John Mashey': '/wiki/John_Mashey',
#  'Yuri Matiyasevich': '/wiki/Yuri_Matiyasevich',
#  'Yukihiro Matsumoto': '/wiki/Yukihiro_Matsumoto',
#  'John Mauchly': '/wiki/John_Mauchly',
#  'Ujjwal Maulik': '/wiki/Ujjwal_Maulik',
#  'Derek McAuley': '/wiki/Derek_McAuley',
#  'John McCarthy': '/wiki/John_McCarthy_(computer_scientist)',
#  'Andrew McCallum': '/wiki/Andrew_McCallum',
#  'Douglas McIlroy': '/wiki/Douglas_McIlroy',
#  'Chris McKinstry': '/wiki/Chris_McKinstry',
#  'Marshall Kirk McKusick': '/wiki/Marshall_Kirk_McKusick',
#  'Lambert Meertens': '/wiki/Lambert_Meertens',
#  'Kurt Mehlhorn': '/wiki/Kurt_Mehlhorn',
#  'Dora Metcalf': '/wiki/Dora_Metcalf',
#  'Bertrand Meyer': '/wiki/Bertrand_Meyer',
#  'Silvio Micali': '/wiki/Silvio_Micali',
#  'Robin Milner': '/wiki/Robin_Milner',
#  'Jack Minker': '/wiki/Jack_Minker',
#  'Marvin Minsky': '/wiki/Marvin_Minsky',
#  'James G. Mitchell': '/wiki/James_G._Mitchell',
#  'Tom M. Mitchell': '/wiki/Tom_M._Mitchell',
#  'Arvind Mithal': '/wiki/Arvind_(computer_scientist)',
#  'Paul Mockapetris': '/wiki/Paul_Mockapetris',
#  'Cleve Moler': '/wiki/Cleve_Moler',
#  'Faron Moller': '/wiki/Faron_Moller',
#  'John P. Moon': '/wiki/John_P._Moon',
#  'Charles H. Moore': '/wiki/Charles_H._Moore',
#  'Edward F. Moore': '/wiki/Edward_F._Moore',
#  'Gordon Moore': '/wiki/Gordon_Moore',
#  'J Strother Moore': '/wiki/J_Strother_Moore',
#  'Roger Moore': '/wiki/Roger_Moore_(computer_scientist)',
#  'Hans Moravec': '/wiki/Hans_Moravec',
#  'Carroll Morgan': '/wiki/Carroll_Morgan_(computer_scientist)',
#  'Robert Tappan Morris': '/wiki/Robert_Tappan_Morris',
#  'Joel Moses': '/wiki/Joel_Moses',
#  'Rajeev Motwani': '/wiki/Rajeev_Motwani',
#  'Oleg A. Mukhanov': '/wiki/Oleg_A._Mukhanov',
#  'Stephen Muggleton': '/wiki/Stephen_Muggleton',
#  'Klaus-Robert Müller': '/wiki/Klaus-Robert_M%C3%BCller',
#  'Alan Mycroft': '/wiki/Alan_Mycroft',
#  'Brad A. Myers': '/wiki/Brad_A._Myers',
#  'Mihai Nadin': '/wiki/Mihai_Nadin',
#  'Makoto Nagao': '/wiki/Makoto_Nagao',
#  'Frieder Nake': '/wiki/Frieder_Nake',
#  'Bonnie Nardi': '/wiki/Bonnie_Nardi',
#  'Peter Naur': '/wiki/Peter_Naur',
#  'Roger Needham': '/wiki/Roger_Needham',
#  'James G. Nell': '/wiki/James_G._Nell',
#  'Greg Nelson': '/wiki/Greg_Nelson_(computer_scientist)',
#  'Bernard de Neumann': '/wiki/Bernard_de_Neumann',
#  'Klara Dan von Neumann': '/wiki/Klara_Dan_von_Neumann',
#  'John von Neumann': '/wiki/John_von_Neumann',
#  'Allen Newell': '/wiki/Allen_Newell',
#  'Max Newman': '/wiki/Max_Newman',
#  'Andrew Ng': '/wiki/Andrew_Ng',
#  'Nils John Nilsson': '/wiki/Nils_John_Nilsson',
#  'G.M. Nijssen': '/wiki/G.M._Nijssen',
#  'Tobias Nipkow': '/wiki/Tobias_Nipkow',
#  'Maurice Nivat': '/wiki/Maurice_Nivat',
#  'Phiwa Nkambule': '/wiki/Phiwa_Nkambule',
#  'Jerre Noe': '/wiki/Jerre_Noe',
#  'Peter Nordin': '/wiki/Peter_Nordin',
#  'Donald Norman': '/wiki/Donald_Norman',
#  'Peter Norvig': '/wiki/Peter_Norvig',
#  'George Novacky': '/wiki/George_Novacky',
#  'Kristen Nygaard': '/wiki/Kristen_Nygaard',
#  'Martin Odersky': '/wiki/Martin_Odersky',
#  "Peter O'Hearn": '/wiki/Peter_O%27Hearn',
#  'T. William Olle': '/wiki/T._William_Olle',
#  'Steve Omohundro': '/wiki/Steve_Omohundro',
#  'Severo Ornstein': '/wiki/Severo_Ornstein',
#  "John O'Sullivan": '/wiki/John_O%27Sullivan_(engineer)',
#  'John Ousterhout': '/wiki/John_Ousterhout',
#  'Mark Overmars': '/wiki/Mark_Overmars',
#  'Susan Owicki': '/wiki/Susan_Owicki',
#  'Larry Page': '/wiki/Larry_Page',
#  'Sankar Pal': '/wiki/Sankar_Pal',
#  'Paritosh Pandya': '/wiki/Paritosh_Pandya',
#  'Christos Papadimitriou': '/wiki/Christos_Papadimitriou',
#  'David Park': '/wiki/David_Park_(computer_scientist)',
#  'David Parnas': '/wiki/David_Parnas',
#  'DJ Patil': '/wiki/DJ_Patil',
#  'Yale Patt': '/wiki/Yale_Patt',
#  'David Patterson': '/wiki/David_Patterson_(computer_scientist)',
#  'Mike Paterson': '/wiki/Mike_Paterson',
#  'Mihai Pătraşcu': '/wiki/Mihai_P%C4%83tra%C8%99cu_(computer_scientist)',
#  'Lawrence Paulson': '/wiki/Lawrence_Paulson',
#  'Randy Pausch': '/wiki/Randy_Pausch',
#  'Juan Pavón': '/wiki/Juan_Pav%C3%B3n',
#  'Judea Pearl': '/wiki/Judea_Pearl',
#  'Alan Perlis': '/wiki/Alan_Perlis',
#  'Radia Perlman': '/wiki/Radia_Perlman',
#  'Pier Giorgio Perotto': '/wiki/Pier_Giorgio_Perotto',
#  'Rózsa Péter': '/wiki/R%C3%B3zsa_P%C3%A9ter',
#  'Simon Peyton Jones': '/wiki/Simon_Peyton_Jones',
#  'Kathy Pham': '/wiki/Kathy_Pham',
#  'Roberto Pieraccini': '/wiki/Roberto_Pieraccini',
#  'Gordon Plotkin': '/wiki/Gordon_Plotkin',
#  'Amir Pnueli': '/wiki/Amir_Pnueli',
#  'Willem van der Poel': '/wiki/Willem_van_der_Poel',
#  'Cicely Popplewell': '/wiki/Cicely_Popplewell',
#  'Emil Post': '/wiki/Emil_Post',
#  'Jon Postel': '/wiki/Jon_Postel',
#  'Franco Preparata': '/wiki/Franco_Preparata',
#  'William H. Press': '/wiki/William_H._Press',
#  'Rapelang Rabana': '/wiki/Rapelang_Rabana',
#  'Grzegorz Rozenberg': '/wiki/Grzegorz_Rozenberg',
#  'Michael O. Rabin': '/wiki/Michael_O._Rabin',
#  'Dragomir R. Radev': '/wiki/Dragomir_R._Radev',
#  'T. V. Raman': '/wiki/T._V._Raman',
#  'Brian Randell': '/wiki/Brian_Randell',
#  'Anders P. Ravn': '/wiki/Anders_P._Ravn',
#  'Raj Reddy': '/wiki/Raj_Reddy',
#  'David P. Reed': '/wiki/David_P._Reed',
#  'Trygve Reenskaug': '/wiki/Trygve_Reenskaug',
#  'John C. Reynolds': '/wiki/John_C._Reynolds',
#  'Joyce K. Reynolds': '/wiki/Joyce_K._Reynolds',
#  'Reinder van de Riet': '/wiki/Reinder_van_de_Riet',
#  'Bernard Richards': '/wiki/Bernard_Richards',
#  'Martin Richards': '/wiki/Martin_Richards_(computer_scientist)',
#  'Adam Riese': '/wiki/Adam_Riese',
#  'C. J. van Rijsbergen': '/wiki/C._J._van_Rijsbergen',
#  'Dennis Ritchie': '/wiki/Dennis_Ritchie',
#  'Ron Rivest': '/wiki/Ron_Rivest',
#  'Ken Robinson': '/wiki/Ken_Robinson_(computer_scientist)',
#  'Colette Rolland': '/wiki/Colette_Rolland',
#  'John Romero': '/wiki/John_Romero',
#  'Azriel Rosenfeld': '/wiki/Azriel_Rosenfeld',
#  'Douglas T. Ross': '/wiki/Douglas_T._Ross',
#  'Guido van Rossum': '/wiki/Guido_van_Rossum',
#  'M. A. Rothman': '/wiki/M._A._Rothman',
#  'Winston W. Royce': '/wiki/Winston_W._Royce',
#  'Rudy Rucker': '/wiki/Rudy_Rucker',
#  'Steven Rudich': '/wiki/Steven_Rudich',
#  'Jeff Rulifson': '/wiki/Jeff_Rulifson',
#  'James Rumbaugh': '/wiki/James_Rumbaugh',
#  'Peter Ružička': '/wiki/Peter_Ru%C5%BEi%C4%8Dka',
#  'George Sadowsky': '/wiki/George_Sadowsky',
#  'Umar Saif': '/wiki/Umar_Saif',
#  'Gerard Salton': '/wiki/Gerard_Salton',
#  'Jean E. Sammet': '/wiki/Jean_E._Sammet',
#  'Claude Sammut': '/wiki/Claude_Sammut',
#  'Carl Sassenrath': '/wiki/Carl_Sassenrath',
#  'Mahadev Satyanarayanan': '/wiki/Mahadev_Satyanarayanan',
#  'Walter Savitch': '/wiki/Walter_Savitch',
#  'Jonathan Schaeffer': '/wiki/Jonathan_Schaeffer',
#  'Wilhelm Schickard': '/wiki/Wilhelm_Schickard',
#  'Jürgen Schmidhuber': '/wiki/J%C3%BCrgen_Schmidhuber',
#  'Steve Schneider': '/wiki/Steve_Schneider_(computer_scientist)',
#  'Bruce Schneier': '/wiki/Bruce_Schneier',
#  'Fred B. Schneider': '/wiki/Fred_B._Schneider',
#  'Sarita Schoenebeck': '/wiki/Sarita_Schoenebeck',
#  'Glenda Schroeder': '/wiki/Glenda_Schroeder',
#  'Bernhard Schölkopf': '/wiki/Bernhard_Sch%C3%B6lkopf',
#  'Dana Scott': '/wiki/Dana_Scott',
#  'Michael L. Scott': '/wiki/Michael_L._Scott',
#  'Robert Sedgewick': '/wiki/Robert_Sedgewick_(computer_scientist)',
#  'Ravi Sethi': '/wiki/Ravi_Sethi',
#  'Nigel Shadbolt': '/wiki/Nigel_Shadbolt',
#  'Adi Shamir': '/wiki/Adi_Shamir',
#  'Claude Shannon': '/wiki/Claude_Shannon',
#  'David E. Shaw': '/wiki/David_E._Shaw',
#  'Cliff Shaw': '/wiki/Cliff_Shaw',
#  'Scott Shenker': '/wiki/Scott_Shenker',
#  'Ben Shneiderman': '/wiki/Ben_Shneiderman',
#  'Edward H. Shortliffe': '/wiki/Edward_H._Shortliffe',
#  'Daniel Siewiorek': '/wiki/Daniel_Siewiorek',
#  'Joseph Sifakis': '/wiki/Joseph_Sifakis',
#  'Herbert A. Simon': '/wiki/Herbert_A._Simon',
#  'Munindar P. Singh': '/wiki/Munindar_P._Singh',
#  'Ramesh Sitaraman': '/wiki/Ramesh_Sitaraman',
#  'Daniel Sleator': '/wiki/Daniel_Sleator',
#  'Aaron Sloman': '/wiki/Aaron_Sloman',
#  'Arne Sølvberg': '/wiki/Arne_S%C3%B8lvberg',
#  'Brian Cantwell Smith': '/wiki/Brian_Cantwell_Smith',
#  'David Canfield Smith': '/wiki/David_Canfield_Smith',
#  'Steven Spewak': '/wiki/Steven_Spewak',
#  'Carol Spradling': '/wiki/Carol_Spradling',
#  'Robert Sproull': '/wiki/Robert_Sproull',
#  'Rohini Kesavan Srihari': '/wiki/Rohini_Kesavan_Srihari',
#  'Sargur Srihari': '/wiki/Sargur_Srihari',
#  'Maciej Stachowiak': '/wiki/Maciej_Stachowiak',
#  'Richard Stallman': '/wiki/Richard_Stallman',
#  'Ronald Stamper': '/wiki/Ronald_Stamper',
#  'Richard E. Stearns': '/wiki/Richard_E._Stearns',
#  'Guy L. Steele, Jr.': '/wiki/Guy_L._Steele,_Jr.',
#  'Thomas Sterling': '/wiki/Thomas_Sterling_(computing)',
#  'Alexander Stepanov': '/wiki/Alexander_Stepanov',
#  'W. Richard Stevens': '/wiki/W._Richard_Stevens',
#  'Larry Stockmeyer': '/wiki/Larry_Stockmeyer',
#  'Salvatore Stolfo': '/wiki/Salvatore_Stolfo',
#  'Michael Stonebraker': '/wiki/Michael_Stonebraker',
#  'Olaf Storaasli': '/wiki/Olaf_Storaasli_(computing)',
#  'Christopher Strachey': '/wiki/Christopher_Strachey',
#  'Volker Strassen': '/wiki/Volker_Strassen',
#  'Bjarne Stroustrup': '/wiki/Bjarne_Stroustrup',
#  'Madhu Sudan': '/wiki/Madhu_Sudan',
#  'Gerald Jay Sussman': '/wiki/Gerald_Jay_Sussman',
#  'Bert Sutherland': '/wiki/Bert_Sutherland',
#  'Ivan Sutherland': '/wiki/Ivan_Sutherland',
#  'Latanya Sweeney': '/wiki/Latanya_Sweeney',
#  'Mario Szegedy': '/wiki/Mario_Szegedy',
#  'Parisa Tabriz': '/wiki/Parisa_Tabriz',
#  'Roberto Tamassia': '/wiki/Roberto_Tamassia',
#  'Andrew S. Tanenbaum': '/wiki/Andrew_S._Tanenbaum',
#  'Austin Tate': '/wiki/Austin_Tate',
#  'Bernhard Thalheim': '/wiki/Bernhard_Thalheim',
#  'Éva Tardos': '/wiki/%C3%89va_Tardos',
#  'Gábor Tardos': '/wiki/G%C3%A1bor_Tardos',
#  'Robert Tarjan': '/wiki/Robert_Tarjan',
#  'Valerie Taylor': '/wiki/Valerie_Taylor_(computer_scientist)',
#  'Mario Tchou': '/wiki/Mario_Tchou',
#  'Jaime Teevan': '/wiki/Jaime_Teevan',
#  'Shang-Hua Teng': '/wiki/Shang-Hua_Teng',
#  'Larry Tesler': '/wiki/Larry_Tesler',
#  'Avie Tevanian': '/wiki/Avie_Tevanian',
#  'Charles P. Thacker': '/wiki/Charles_P._Thacker',
#  'Daniel Thalmann': '/wiki/Daniel_Thalmann',
#  'Ken Thompson': '/wiki/Ken_Thompson_(computer_programmer)',
#  'Sebastian Thrun': '/wiki/Sebastian_Thrun',
#  'Walter F. Tichy': '/wiki/Walter_F._Tichy',
#  'Seinosuke Toda': '/wiki/Seinosuke_Toda',
#  'Linus Torvalds': '/wiki/Linus_Torvalds',
#  'Leonardo Torres y Quevedo': '/wiki/Leonardo_Torres_y_Quevedo',
#  'Godfried Toussaint': '/wiki/Godfried_Toussaint',
#  'Gloria Townsend': '/wiki/Gloria_Townsend',
#  'Edwin E. Tozer': '/wiki/Edwin_E._Tozer',
#  'Joseph F Traub': '/wiki/Joseph_F_Traub',
#  'John V. Tucker': '/wiki/John_V._Tucker',
#  'John Tukey': '/wiki/John_Tukey',
#  'Alan Turing': '/wiki/Alan_Turing',
#  'David Turner': '/wiki/David_Turner_(computer_scientist)',
#  'Murray Turoff': '/wiki/Murray_Turoff',
#  'Jeffrey D. Ullman': '/wiki/Jeffrey_D._Ullman',
#  'Leslie Valiant': '/wiki/Leslie_Valiant',
#  'Vladimir Vapnik': '/wiki/Vladimir_Vapnik',
#  'Moshe Vardi': '/wiki/Moshe_Vardi',
#  'Dorothy Vaughan': '/wiki/Dorothy_Vaughan',
#  'Umesh Vazirani': '/wiki/Umesh_Vazirani',
#  'Manuela M. Veloso': '/wiki/Manuela_M._Veloso',
#  'François Vernadat': '/wiki/Fran%C3%A7ois_Vernadat',
#  'Richard Veryard': '/wiki/Richard_Veryard',
#  'Sergiy Vilkomir': '/wiki/Sergiy_Vilkomir',
#  'Paul Vitanyi': '/wiki/Paul_Vitanyi',
#  'Andrew Viterbi': '/wiki/Andrew_Viterbi',
#  'Jeffrey Scott Vitter': '/wiki/Jeffrey_Scott_Vitter',
#  'Paul Vixie': '/wiki/Paul_Vixie',
#  'Eiiti Wada': '/wiki/Eiiti_Wada',
#  'David Wagner': '/wiki/David_A._Wagner',
#  'David Waltz': '/wiki/David_Waltz',
#  'James Z. Wang': '/wiki/James_Z._Wang',
#  'Steve Ward': '/wiki/Steve_Ward_(computer_scientist)',
#  'Manfred K. Warmuth': '/wiki/Manfred_K._Warmuth',
#  'David H. D. Warren': '/wiki/David_H._D._Warren',
#  'Kevin Warwick': '/wiki/Kevin_Warwick',
#  'Jan Weglarz': '/wiki/Jan_Weglarz',
#  'Philip Wadler': '/wiki/Philip_Wadler',
#  'Peter Wegner': '/wiki/Peter_Wegner',
#  'Joseph Henry Wegstein': '/wiki/Joseph_Henry_Wegstein',
#  'Peter J. Weinberger': '/wiki/Peter_J._Weinberger',
#  'Mark Weiser': '/wiki/Mark_Weiser',
#  'Joseph Weizenbaum': '/wiki/Joseph_Weizenbaum',
#  'David Wheeler': '/wiki/David_Wheeler_(computer_scientist)',
#  'Franklin H. Westervelt': '/wiki/Franklin_H._Westervelt',
#  'Steve Whittaker': '/wiki/Steve_Whittaker',
#  'Jennifer Widom': '/wiki/Jennifer_Widom',
#  'Gio Wiederhold': '/wiki/Gio_Wiederhold',
#  'Norbert Wiener': '/wiki/Norbert_Wiener',
#  'Adriaan van Wijngaarden': '/wiki/Adriaan_van_Wijngaarden',
#  'Mary Allen Wilkes': '/wiki/Mary_Allen_Wilkes',
#  'Maurice Vincent Wilkes': '/wiki/Maurice_Vincent_Wilkes',
#  'Yorick Wilks': '/wiki/Yorick_Wilks',
#  'James H. Wilkinson': '/wiki/James_H._Wilkinson',
#  'Sophie Wilson': '/wiki/Sophie_Wilson',
#  'Shmuel Winograd': '/wiki/Shmuel_Winograd',
#  'Terry Winograd': '/wiki/Terry_Winograd',
#  'Patrick Winston': '/wiki/Patrick_Winston',
#  'Niklaus Wirth': '/wiki/Niklaus_Wirth',
#  'Neil Wiseman': '/wiki/Neil_Wiseman',
#  'Dennis E. Wisnosky': '/wiki/Dennis_E._Wisnosky',
#  'Stephen Wolfram': '/wiki/Stephen_Wolfram',
#  'Mike Woodger': '/wiki/Mike_Woodger',
#  'Philip Woodward': '/wiki/Philip_Woodward',
#  'Beatrice Helen Worsley': '/wiki/Beatrice_Helen_Worsley',
#  'Steve Wozniak': '/wiki/Steve_Wozniak',
#  'Jie Wu': '/wiki/Jie_Wu',
#  'William Wulf': '/wiki/William_Wulf',
#  'Mihalis Yannakakis': '/wiki/Mihalis_Yannakakis',
#  'Andrew Chi-Chih Yao': '/wiki/Andrew_Chi-Chih_Yao',
#  'John Yen': '/wiki/John_Yen',
#  'Nobuo Yoneda': '/wiki/Nobuo_Yoneda',
#  'Edward Yourdon': '/wiki/Edward_Yourdon',
#  'Moti Yung': '/wiki/Moti_Yung',
#  'Lotfi Zadeh': '/wiki/Lotfi_Zadeh',
#  'Hans Zantema': '/wiki/Hans_Zantema',
#  'Arif Zaman': '/wiki/Arif_Zaman',
#  'Stanley Zdonik': '/wiki/Stanley_Zdonik',
#  'Hussein Zedan': '/wiki/Hussein_Zedan',
#  'Shlomo Zilberstein': '/wiki/Shlomo_Zilberstein',
#  'Jill Zimmerman': '/wiki/Jill_Zimmerman',
#  'Konrad Zuse': '/wiki/Konrad_Zuse',
#  'Lists portal': '/wiki/Portal:Lists',
#  'List of computing people': '/wiki/List_of_computing_people',
#  'List of important publications in computer science': '/wiki/List_of_important_publications_in_computer_science',
#  'List of Jewish American computer scientists': '/wiki/List_of_Jewish_American_computer_scientists',
#  'List of members of the National Academy of Sciences (computer and information sciences)': '/wiki/List_of_members_of_the_National_Academy_of_Sciences_(computer_and_information_sciences)',
#  'List of pioneers in computer science': '/wiki/List_of_pioneers_in_computer_science',
#  'List of programmers': '/wiki/List_of_programmers',
#  'List of programming language researchers': '/wiki/List_of_programming_language_researchers',
#  'List of Russian IT developers': '/wiki/List_of_Russian_IT_developers',
#  'List of Slovenian computer scientists': '/wiki/List_of_Slovenian_computer_scientists',
#  'List of Indian computer scientists': '/wiki/List_of_Indian_computer_scientists'}

# %%
def search_wiki_awards(name):
    try:
        # Search for the Wikipedia page of the person
        page = wikipedia.page(name)
    except (wikipedia.exceptions.PageError, wikipedia.exceptions.DisambiguationError):
        try:
        # Search for the Wikipedia page of the person
            page = wikipedia.page('/wiki/'+name)
        except:
            return 0
        # Get the content of the page
    content = page.content
        
    try:
        # Find the section on education
        awards_text = content.split("== Awards ==")[1].split("==")[0]

        return len([s for s in awards_text.splitlines() if len(s) > 3])
    except IndexError:
        return 0

# %%
data = []
i = 1

for scientist, page_url in scientists.items():
    # if i == 10: break
    i += 1
    
    # helper variables
    education = ''
    awards = 0
    
    # make the request to the server
    request = get(base_url + page_url)

    # get the html content
    response = BeautifulSoup(request.content, 'html.parser')

    # main content
    content = response.find("div", {"class": "mw-parser-output"})

    # table info of scientist
    table = response.find("table", {"class": "infobox biography vcard"})
        
    # get headers and paragraphs
    header = content.find_all("h2")
    par = content.find_all("p")
    
    # if table exists
    if table:
        # for each row of the body table
        for row in table.find_all("tr"):
            # if there is a Awards header
            if row.find("th", {"class": "infobox-label"}, text=compile("Awards")):
                # get number  of awards
                awards = len(row.find_all("li"))
                
    if not awards:        
        awards = search_wiki_awards(scientist)
    
    ids = [
            "Education", "Education_and_early_life", "Education_and_career", "Early_life_and_education",
            "Early_life", "Life", "Life_and_career", "Life_and_work", "Biography", "Career"
          ]
    
    done = False
    # for each header and paragraph
    for h, p in zip(header, par):
        # for each possible span id
        for _id in ids:
            # if header contains one span with _id
            if h.find("span", {"id": _id}):
                education = p.text # get info
                done = True
                break
        if done: break
            
    # append final data
    data += [(scientist, awards, " ".join(simple_preprocess(education)))]

# %%
df = DataFrame(data, columns=['Name', 'Awards', 'Education'])

# %%
df
# Out:
#                                          Name  Awards  \
# 0                         Atta ur Rehman Khan       8
# 1                           Wil van der Aalst       0
# 2                              Scott Aaronson       4
# 3                                Rediet Abebe       3
# 4                                 Hal Abelson       1
# ..                                        ...     ...
# 676                       List of programmers       0
# 677  List of programming language researchers       0
# 678             List of Russian IT developers       0
# 679     List of Slovenian computer scientists       0
# 680        List of Indian computer scientists       0
#
#                                              Education
# 0    khan was bright sparks scholar and received hi...
# 1    willibrordus martinus pancratius van der aalst...
# 2    scott joel aaronson born may is an american th...
# 3    abebe research develops mathematical and compu...
# 4    he directed the first implementation of the la...
# ..                                                 ...
# 676
# 677
# 678
# 679
# 680
#
# [681 rows x 3 columns]

# %%
df = df[df['Education']  != '']

# %%
df
# Out:
#                     Name  Awards  \
# 0    Atta ur Rehman Khan       8
# 1      Wil van der Aalst       0
# 2         Scott Aaronson       4
# 3           Rediet Abebe       3
# 4            Hal Abelson       1
# ..                   ...     ...
# 660       Edward Yourdon       0
# 661            Moti Yung       6
# 663         Hans Zantema       0
# 665       Stanley Zdonik       0
# 668       Jill Zimmerman       0
#
#                                              Education
# 0    khan was bright sparks scholar and received hi...
# 1    willibrordus martinus pancratius van der aalst...
# 2    scott joel aaronson born may is an american th...
# 3    abebe research develops mathematical and compu...
# 4    he directed the first implementation of the la...
# ..                                                 ...
# 660  yourdon obtained his in applied mathematics fr...
# 661  yung earned his phd from columbia university i...
# 663  born in goingarijp the netherlands zantema rec...
# 665  stanley zdonik zəˈdɒnɪk zə don ik is computer ...
# 668  jill loraine zimmerman born march is an americ...
#
# [453 rows x 3 columns]

# %%
df.to_csv('List_of_computer_scientists.csv', index=False)
